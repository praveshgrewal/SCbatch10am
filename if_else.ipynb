# %% [markdown]
# ## if else

# %%
age = 2
if age > 18:
    print("you can vote")
else:
    print("abhi tu bacha hai!")
# Out:
# abhi tu bacha hai!

# %%
age = 45
result = "adult"  if age > 18 else "child"
print(result)
# Out:
# adult

# %%
name = "ankit"
if name == "piyush":
    print("my name is piyush")
else:
    print("i don't know my name")
# Out:
# i don't know my name

# %%
num = 67
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %% [markdown]
# ## if else elif

# %%
age = 2

if age >= 60:
    print("senior")
elif age >= 30:
    print("adult")
elif age > 18:
    print("young")
else:
    print("bache ho abhi")
# Out:
# bache ho abhi

# %% [markdown]
# ## nested if else

# %%
num = -67
if num > 0:
    if num % 2 == 0:
        print("even")
    else:
        print("odd")
else:
    print("negative value")
# Out:
# negative value

# %%
salary = 90000
credit = 670

if salary > 50000:
    if credit > 700:
        print("you can get a credit card")
    else:
        print("cibil is low")
else:
    print("salary is low")
# Out:
# cibil is low

# %%
salary = 90000
credit = 670

if (salary > 50000 and credit > 700):
    print("can get credi card")
else:
    print("work on credit score")
# Out:
# work on credit score

# %% [markdown]
# ### username and password --> admin ,1234 , "accessn granted , denied

# %%
username = input("enter your username: ")
password = input("enter your password: ")

if username == "admin" and password == "1234":
    print("access granted")
else:
    print("denied")
# Out:
# denied

# %%
### divisible by 4. divisible by 100 , divisible by 400

# %%
year = 2024

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2024 is a leap year.

# %% [markdown]
# ### user input vowel and const

# %%
user = input("enter a char: ")

output = "vowel" if user in "aeiou" else "const"
print(output)
# Out:
# vowel

# %% [markdown]
# ### zoo ticket price check , agar age 18 + hai to $ 20 ticket price child price will be 10 and we will give discount agar aaj saturday hai to of $5

# %%
age = 2
day = "saturday"

price = 20 if age > 18 else 10

if day == "saturday":
    price -= 5 # price = price - 5
print(f"today price for ${price}")
# Out:
# today price for $5

# %%
name = "deepika"
age = 21

print("my name is",name,"i am ",age,"years  old ")
# Out:
# my name is deepika i am  21 years  old

# %%
print(f"my name is {name} and i am {age} years old")
# Out:
# my name is deepika and i am 21 years old
