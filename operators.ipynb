# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 12
num2 = 12
print(num+num2) # additon
print(num-num2) # sub
print(num*num2) # muli
print(num/num2) # divison ---> float
print(num//num2) # floor divison ---> int
print(num%num2) # reminder
print(num**num2) # power (exponentioal)
# Out:
# 24
# 0
# 144
# 1.0
# 1
# 0
# 8916100448256

# %% [markdown]
# ## assignment

# %%
x = 12 # equal 
print(x)
# Out:
# 12

# %%
x = x + 3
x
# Out:
# 15

# %%
x += 3 # x = x + 3
x
# Out:
# 18

# %%
x-= 3
x
# Out:
# 15

# %%
x*=3
x
# Out:
# 45

# %% [markdown]
# ## logical operators
# * and ---> both condition should be true
# * or ---> at least one should be true
# * not ---> reverse ---> True--->False .

# %%
print(True and True)
print(True and False)
print(True or False)
print(not True)
# Out:
# True
# False
# True
# False

# %%
(10>5)and  (10<6)
# Out:
# False

# %% [markdown]
# ## relationl / comparision
# * equal to (==)
# * not equal to (!=)
# * less then ( < )
# * less then equal to ( <= )
# * greather then (> )
# * greater then equal to (> =)

# %%
a = 100
b = 10
print(a == b )
print(a != b )
print(a > b )
print(a >= b )
print(a < b )
print(a <= b )
# Out:
# False
# True
# True
# True
# False
# False

# %% [markdown]
# ## membership opera

# %%
names = ['ankit','aashish','rehman','danish','sahil']
print('rehman' in names)
# Out:
# True

# %%
name = "jiger"
print('g' in name)
print('g' not in name)
# Out:
# True
# False

# %% [markdown]
# ## identity operators
# * is
# * is not

# %%
n1 = 10
print(id(n1))
n2 = 10
print(id(n2))
n3 = 56
print(id(n3))
print(n1 is n2)
print(n1 is n3)
print(n1 is not  n3)
# Out:
# 4323601112
# 4323601112
# 4323602584
# True
# False
# True

# %% [markdown]
# ## input ---> to take input from user's

# %%
naam = input('Enter Your Name: ')
surname = input('Enter Your Surname: ')
print(naam + ' ', surname)
# Out:
# rehman  danish

# %% [markdown]
# #### by default input will consider value as a string

# %%
num5 = int(input('Enter Your 1st number : '))
num6 = int(input('Enter Your 2nd number : '))
print(num5+num6)
# Out:
# 22
