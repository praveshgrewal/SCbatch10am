# %%
# !pip install numpy

# %%
import numpy as np

# %%
arr = np.array([[1,2,3,4,5]])
print(arr)
# Out:
# [[1 2 3 4 5]]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape
# Out:
# (1, 5)

# %%
arr = np.array([[1,2,3,4,5]])
print(arr)
arr.dtype
# Out:
# [[1 2 3 4 5]]
# dtype('int64')

# %%
arr_float = arr.astype('float')
arr_float
# Out:
# array([[1., 2., 3., 4., 5.]])

# %%
nums = np.array([1,4,8,9,12],dtype='float')
nums
# Out:
# array([ 1.,  4.,  8.,  9., 12.])

# %%
# num2 = np.array([1,2,3,4,5,6])
# num2.reshape(3,3) # rows ,columns

# %%
num3 = np.array([[1,2,3],[4,5,6]])

# %%
num3.ndim
# Out:
# 2

# %%
num3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.hsplit(num3,3)
# Out:
# [array([[1],
#         [4]]),
#  array([[2],
#         [5]]),
#  array([[3],
#         [6]])]

# %%
np.vsplit(num3,2)
# Out:
# [array([[1, 2, 3]]), array([[4, 5, 6]])]

# %%
num4 = np.random.rand(3,4)

# %%
num5 = num4*200

num5
# Out:
# array([[176.13936511,  12.18297284, 100.7263949 ,  11.29992182],
#        [132.43769972,  86.19643685,   7.91650555, 141.23406833],
#        [ 97.89686167,  94.88148263,  79.16041396, 188.79726597]])
