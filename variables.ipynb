# %%
name45 = "hello world" # name is a variable here and hello world is a value
print(name45)
print(id(name45))
# Out:
# hello world
# 4568300592

# %%
name2 = "piyush"
print(name2)
print(id(name2))
# Out:
# piyush
# 4477450304

# %% [markdown]
# ### id ---> to check the memory location

# %%
name = "ahmed faraz"
print(name)
print(id(name))
# Out:
# ahmed faraz
# 4477826224

# %%
age = 34
print(age)
print(id(age))
# Out:
# 34
# 4368231896

# %%
print(id("i love python programming"))
print("hello")
# Out:
# 4477937952
# hello

# %% [markdown]
# ### if your value same then your memory location will be also same

# %%
x = 10
print(id(x))
y = 10
print(id(y))
# Out:
# 4368231128
# 4368231128

# %% [markdown]
# ### comments

# %%
# this is comment in python

# %% [markdown]
# ## rules and ragulation of variables

# %% [markdown]
# ### can't start from a number

# %%
10 = "asish"
print(10)
# Out:
#   Cell In[17], line 1
#     10 = "asish"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### can't use special char and space as well (_)

# %%
name@of = "ankit"
print(name@of)
# Out:
#   Cell In[19], line 1
#     name@of = "ankit"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### python is a case sensitive programming lang --> capital and small alphabet will treat differnent

# %%
Student = "rehman danish "
print(student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 Student = "rehman danish "
# ----> 2 print(student)
#
# NameError: name 'student' is not defined

# %% [markdown]
# ### can't be keyword
# * reserv word's
# * not should be a variable name,file name,function name,class name

# %%
if = "danish"
# Out:
#   Cell In[21], line 1
#     if = "danish"
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### best way to create a variable
# * snake case (name_of_student)
# * always avoid camle case(AbC)

# %%
name_of_student = "danish"
print(name_of_student)
# Out:
# danish

# %%
name23 = "afgani"
print(name23)
# Out:
# afgani

# %%
# 4568300592


name65 = "hello world"
print(id(name65))
# Out:
# 4568296624

# %%
name60 = "python"
print(id(name60))
# Out:
# 4354614224

# %%
name61 = "python"
print(id(name61))
# Out:
# 4354614224

# %%
"""this is multi line comment"""
print("welcome")
# Out:
# welcome
