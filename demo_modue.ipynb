# %%
# from module import add
# # print(greet())
# print(add(12,5))

# %%
import example

# %%
print(example.factorial(5))
print(example.add(5,5))
print(example.sub(5,5))
# Out:
# 120
# 10
# 0

# %%
from example import *

# %%
dir(example)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'factorial',
#  'sub']
