# %%
import pandas as pd
print("imported")
# Out:
# imported

# %% [markdown]
# ## load the dataset

# %%
df = pd.read_csv('mckinsey.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data = {
    'Names':['ankit','rizwan','deepika','danish ur rehman','ayan','sahil'],
    'Age':[23,23,22,23,20,22],
    'Marks':[67,68,45,89,36,22]
}

# %%
data
# Out:
# {'Names': ['ankit', 'rizwan', 'deepika', 'danish ur rehman', 'ayan', 'sahil'],
#  'Age': [23, 23, 22, 23, 20, 22],
#  'Marks': [67, 68, 45, 89, 36, 22]}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#               Names  Age  Marks
# 0             ankit   23     67
# 1            rizwan   23     68
# 2           deepika   22     45
# 3  danish ur rehman   23     89
# 4              ayan   20     36
# 5             sahil   22     22

# %%
df2.to_csv('batch10am.csv',index=False)
print("file stored")
# Out:
# file stored

# %%
df3 = pd.read_csv('batch10am.csv')
df3
# Out:
#               Names  Age  Marks
# 0             ankit   23     67
# 1            rizwan   23     68
# 2           deepika   22     45
# 3  danish ur rehman   23     89
# 4              ayan   20     36
# 5             sahil   22     22

# %%
num = '123456'

list(num)
# Out:
# ['1', '2', '3', '4', '5', '6']

# %%
df.shape
# Out:
# (1704, 6)

# %%
data = {
    "Name": [
        "Aman", "Riya", "Karan", "Sita", "Rahul",
        "Aman", "Priya", "Vikas", "Neha", "Riya",
        "Ankit", "Sita", "Rohit", "Rahul", "Karan"
    ],
    
    "Age": [
        23, 25, 30, 28, 27,
        23, 24, 29, 26, 25,
        31, 28, 32, 27, 30
    ],
    
    "City": [
        "Delhi", "Mumbai", "Pune", "Chennai", "Noida",
        "Delhi", "Kolkata", "Jaipur", "Lucknow", "Mumbai",
        "Bangalore", "Chennai", "Hyderabad", "Noida", "Pune"
    ]
}

# %%
data
# Out:
# {'Name': ['Aman',
#   'Riya',
#   'Karan',
#   'Sita',
#   'Rahul',
#   'Aman',
#   'Priya',
#   'Vikas',
#   'Neha',
#   'Riya',
#   'Ankit',
#   'Sita',
#   'Rohit',
#   'Rahul',
#   'Karan'],
#  'Age': [23, 25, 30, 28, 27, 23, 24, 29, 26, 25, 31, 28, 32, 27, 30],
#  'City': ['Delhi',
#   'Mumbai',
#   'Pune',
#   'Chennai',
#   'Noida',
#   'Delhi',
#   'Kolkata',
#   'Jaipur',
#   'Lucknow',
#   'Mumbai',
#   'Bangalore',
#   'Chennai',
#   'Hyderabad',
#   'Noida',
#   'Pune']}

# %%
df4 = pd.DataFrame(data)
df4
# Out:
#      Name  Age       City
# 0    Aman   23      Delhi
# 1    Riya   25     Mumbai
# 2   Karan   30       Pune
# 3    Sita   28    Chennai
# 4   Rahul   27      Noida
# 5    Aman   23      Delhi
# 6   Priya   24    Kolkata
# 7   Vikas   29     Jaipur
# 8    Neha   26    Lucknow
# 9    Riya   25     Mumbai
# 10  Ankit   31  Bangalore
# 11   Sita   28    Chennai
# 12  Rohit   32  Hyderabad
# 13  Rahul   27      Noida
# 14  Karan   30       Pune

# %%
df4.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13     True
# 14     True
# dtype: bool

# %%
print(df4.duplicated().sum())
# Out:
# 5

# %%
df4.loc[df4.duplicated()]
# Out:
#      Name  Age     City
# 5    Aman   23    Delhi
# 9    Riya   25   Mumbai
# 11   Sita   28  Chennai
# 13  Rahul   27    Noida
# 14  Karan   30     Pune

# %%
df4.drop_duplicates(keep='last')
# Out:
#      Name  Age       City
# 5    Aman   23      Delhi
# 6   Priya   24    Kolkata
# 7   Vikas   29     Jaipur
# 8    Neha   26    Lucknow
# 9    Riya   25     Mumbai
# 10  Ankit   31  Bangalore
# 11   Sita   28    Chennai
# 12  Rohit   32  Hyderabad
# 13  Rahul   27      Noida
# 14  Karan   30       Pune

# %%
import pandas as pd

# %%
users = pd.DataFrame({"userid":[1, 2, 3], "name":["sharadh", "shahid", "khusalli"]})

# %%
users
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users, msgs])
# Out:
#    userid      name        msg
# 0       1   sharadh        NaN
# 1       2    shahid        NaN
# 2       3  khusalli        NaN
# 0       1       NaN        hmm
# 1       1       NaN       acha
# 2       2       NaN  theek hai
# 3       4       NaN       nice

# %%
pd.concat([users, msgs],axis =1)
# Out:
#    userid      name  userid        msg
# 0     1.0   sharadh       1        hmm
# 1     2.0    shahid       1       acha
# 2     3.0  khusalli       2  theek hai
# 3     NaN       NaN       4       nice

# %%
users.merge(msgs, on="userid")
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai
